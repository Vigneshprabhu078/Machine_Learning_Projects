# %% [markdown]
# <a href="https://colab.research.google.com/github/Vigneshprabhu078/Machine_Learning_Projects/blob/main/10_Fraud_Detection_in_Credit_Card_Transactions_Using_Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Fraud Detection in Credit Card Transactions Using Logistic Regression**  - Vignesh Prabhu
#
# project focuses on utilizing logistic regression, a widely-used supervised learning algorithm, to detect fraudulent transactions in credit card data. Logistic regression will be employed to model the probability of a transaction being fraudulent based on various features such as transaction amount, location, time of day, and transaction frequency. The goal is to build a predictive model that can effectively identify fraudulent activities, thereby aiding financial institutions in improving fraud detection measures and enhancing security for cardholders.

# %% [markdown]
# **Import Dependencies**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
#load The Data into DataFrame
credit_data=pd.read_csv("/content/creditcard.csv")

# %%
# To display first 5 rows
credit_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
#To check information
credit_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
#To Check Number of rows and columns
credit_data.shape
# Out:
# (284807, 31)

# %%
#Statistical Measures
credit_data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
#To check missing values
credit_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#To check distribution Legit and Fraud
credit_data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# **Handling Highly Unbalanced Data**
#
# 0- legit
# 1- Fraud

# %%
#sepearte 2 data's for analysis
legit=credit_data[credit_data.Class==0]
fraud=credit_data[credit_data.Class==1]

# %%
legit.shape
# Out:
# (284315, 31)

# %%
fraud.shape
# Out:
# (492, 31)

# %%
#statistical measures
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# Comparing values for both transaction
credit_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# ## **UnderSampling**
#
# Build a sample dataset containing similar distribution of normal transactions and fraudulent transactions

# %%
legit_sample=legit.sample(n=492)

# %%
legit_sample.shape
# Out:
# (492, 31)

# %% [markdown]
# **Concatenate 2 Dataframes**

# %%
new_dataset=pd.concat([legit_sample,fraud],axis=0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 11866    20405.0 -0.735475  0.229341  2.524116 -1.928636 -0.092355  0.277940
# 121776   76314.0  0.832147 -0.873824  1.080332  0.311819 -1.337609 -0.106813
# 99842    67307.0 -1.448171 -1.234939  1.387233  0.301958  3.316164  3.565768
# 220946  142366.0  1.926052 -0.994753 -2.235349 -0.785782 -0.141674 -1.481935
# 36713    38656.0  1.176220 -0.320373  0.892969  1.226910 -0.287607  1.505990
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 11866   0.139942  0.136384  2.517457  ... -0.113111  0.154628 -0.373771
# 121776 -0.473773  0.097426  0.790466  ... -0.058271 -0.283611 -0.064065
# 99842  -1.310460  0.713623  0.409941  ... -0.253547 -0.194718 -0.546134
# 220946  0.450793 -0.590734 -1.047161  ...  0.473978  0.972172 -0.131070
# 36713  -0.893026  0.417668  1.518667  ... -0.011257  0.495004 -0.323102
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94154.597561  0.046745 -0.056887  0.050902  0.012566  0.012575
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.011555 -0.027498 -0.061046  0.046114  ... -0.028449 -0.035756
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.019746  0.011009 -0.044448  0.015658  0.039351 -0.011533  0.024522
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       79.828394
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# **Splitting the data into features and target**

# %%
X=new_dataset.drop(columns='Class',axis=1)
Y=new_dataset['Class']

# %%
print(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 11866    20405.0 -0.735475  0.229341  2.524116 -1.928636 -0.092355  0.277940
# 121776   76314.0  0.832147 -0.873824  1.080332  0.311819 -1.337609 -0.106813
# 99842    67307.0 -1.448171 -1.234939  1.387233  0.301958  3.316164  3.565768
# 220946  142366.0  1.926052 -0.994753 -2.235349 -0.785782 -0.141674 -1.481935
# 36713    38656.0  1.176220 -0.320373  0.892969  1.226910 -0.287607  1.505990
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(Y)
# Out:
# 11866     0
# 121776    0
# 99842     0
# 220946    0
# 36713     0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %% [markdown]
# **Spliting Training and Testing Data's**

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %%
X_train.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 100623   67571.0 -0.758469 -0.045410 -0.168438 -1.313275 -1.901763  0.739433
# 100472   67526.0 -0.479887 -0.530553  1.102499 -1.990008  1.031672  4.485764
# 148958   90361.0 -0.678779  0.991466  0.119820 -0.330036  0.394635 -1.150322
# 273436  165587.0  2.040566 -0.469479 -0.915742 -0.121609 -0.032704  0.474445
# 138398   82634.0  1.214490  0.225886  0.303562  0.586963 -0.410954 -0.773664
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 100623  3.071892 -0.483422  0.618203  ... -0.032500  0.042619  0.397224
# 100472 -1.509513  1.228190  0.123228  ...  0.174727  0.196829  0.652599
# 148958  0.781725 -0.189852  1.334167  ... -0.257815 -0.431116 -0.686507
# 273436 -0.750630  0.311561  1.405643  ... -0.288186 -0.164847 -0.494335
# 138398 -0.092999  0.006940 -0.058293  ... -0.142758 -0.249428 -0.808673
#
# ...

# %% [markdown]
# **Model Training**

# %%
#Model Building
log_model = LogisticRegression(max_iter=1000)  # Increase max_iter to 1000 or more

# %%
#Model Training
log_model.fit(X_train,Y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# **Model Evaluation**

# %%
#accuracy score on training data
X_train_prediction=log_model.predict(X_train)
training_data_accuracy=accuracy_score(X_train_prediction,Y_train)
print('Accuracy on Training data : ',training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9466327827191868

# %%
#accuracy score on test data
X_test_prediction=log_model.predict(X_test)
test_data_accuracy=accuracy_score(X_test_prediction,Y_test)
print('Accuracy on Test data : ',test_data_accuracy)
# Out:
# Accuracy on Test data :  0.9238578680203046
